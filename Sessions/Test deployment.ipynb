# %%
import joblib
import numpy as np
from PIL import Image

# Load the saved model
model = joblib.load('C:/Users/Janus/Datascience/Assignments/Sessions/deploy/hmodel.pkl')

# Load the new image
image = Image.open("C:/Users/Janus/Datascience/Assignments/Sessions/Data/tiny_obama.jpg")
# Out:
# C:\Users\Janus\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but KMeans was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [4], line 18
#      15 image_vector = image_array.reshape(1, -1)
#      17 # Use the model to make predictions on the new image
# ---> 18 prediction = model.predict(image_vector)
#      20 # Print the predicted label
#      21 print(prediction)
#
# File ~\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1058, in _BaseKMeans.predict(self, X, sample_weight)
#    1036 """Predict the closest cluster each sample in X belongs to.
#    1037
#    1038 In the vector quantization literature, `cluster_centers_` is called
#    (...)
#    1054     Index of the cluster each sample belongs to.
#    1055 """
#    1056 check_is_fitted(self)
# ...

# %%
OUR_IMAGE = "C:/Users/Janus/Datascience/Assignments/Sessions/Data/tiny_obama.jpg"
image = Image.open(OUR_IMAGE)
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=519x498>
